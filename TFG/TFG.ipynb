# %% [markdown]
# # Graph Convolutional Networks for 3D garment registration
#
# ## author: Ángel Morales Carrasco
#
# This notebook can be used to train the models seen on the results section. It is recommended to use Google collab to do it, as it provides free GPU environments. To make it, we may need to change several paths inside the code and the execution arguments to indicate where we can find the data required to train the models.
#
# For space reasons, I removed the model_m.pkl and model_f.pkl files that defined the SMPL model and need to be downloaded and included in the project to be able to execute it.

# %%
# !pip install tensorflow-graphics-gpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # STRETCHING MODEL

# %%
# %run /content/drive/MyDrive/UB/TFG/TFG_Model/train_stretch.py 0 stretch_sample_00016_Losses /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/autoencoder_0.npy
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# %run /content/drive/MyDrive/UB/TFG/TFG_Model/load_garment_and_body.py

# %%
# %run /content/drive/MyDrive/UB/TFG/TFG_Model/display_model.py /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/autoencoder_0.npy

# %%
# %run /content/drive/MyDrive/UB/TFG/TFG_Model/display_model.py /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/stretch_sample_00016_100_0.npy

# %%
# %run /content/drive/MyDrive/UB/TFG/TFG_Model/display_model.py /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/stretch_sample_01643_100_0.npy

# %%
# %run /content/drive/MyDrive/UB/TFG/TFG_Model/display_model.py /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/stretch_sample_02179_100_0.npy

# %%
# %run /content/drive/MyDrive/UB/TFG/TFG_Model/display_model.py /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/stretch_sample_04846_100_0.npy

# %%
# %run /content/drive/MyDrive/UB/TFG/TFG_Model/display_model.py /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/stretch_sample_05207_100_0.npy

# %% [markdown]
# # REGISTER MODEL

# %%
# %run /content/drive/MyDrive/UB/TFG/TFG_Model/train_register.py 0 register_sample_00016_Losses /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/stretch_sample_00016_Losses_100_0.npy /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/autoencoder_0.npy
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# %run /content/drive/MyDrive/UB/TFG/TFG_Model/display_model_register.py /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/stretch_sample_00016_100_0.npy /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/register_sample_00016_100_0.npy
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# %run /content/drive/MyDrive/UB/TFG/TFG_Model/display_model_register.py /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/stretch_sample_01643_100_0.npy /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/register_sample_01643_100_0.npy

# %%
# %run /content/drive/MyDrive/UB/TFG/TFG_Model/display_model_register.py /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/stretch_sample_02179_100_0.npy /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/register_sample_02179_100_0.npy

# %%
# %run /content/drive/MyDrive/UB/TFG/TFG_Model/display_model_register.py /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/stretch_sample_04846_100_0.npy /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/register_sample_04846_100_0.npy

# %%
# %run /content/drive/MyDrive/UB/TFG/TFG_Model/display_model_register.py /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/stretch_sample_05207_100_0.npy /content/drive/MyDrive/UB/TFG/TFG_Model/checkpoints/register_sample_05207_100_0.npy

# %% [markdown]
# # OBTAINED FINAL LOSSES

# %% [markdown]
# # STRETCH TRAINS
# ## 01643
# Epoch 100
# --------------------------
# Training...
# ---NORMAL LOSS---
# tf.Tensor(10.70532, shape=(), dtype=float32)
# -----------------
# ---VERT LOSS---
# tf.Tensor(2.8015463, shape=(), dtype=float32)
# -----------------
# ---COLL LOSS---
# tf.Tensor(1.0065246, shape=(), dtype=float32)
# -----------------
# ---EDGE LOSS---
# tf.Tensor(1.7641408, shape=(), dtype=float32)
# -----------------
# ---DIST LOSS---
# tf.Tensor(0.074037805, shape=(), dtype=float32)
# -----------------
# ---TOTAL LOSS---
# tf.Tensor(16.35157, shape=(), dtype=float32)
# -----------------
#
# ## 00016
#
# Epoch 100
# --------------------------
# Training...
# ---NORMAL LOSS---
# tf.Tensor(7.217782, shape=(), dtype=float32)
# -----------------
# ---VERT LOSS---
# tf.Tensor(1.2818129, shape=(), dtype=float32)
# -----------------
# ---COLL LOSS---
# tf.Tensor(0.36556184, shape=(), dtype=float32)
# -----------------
# ---EDGE LOSS---
# tf.Tensor(0.63180006, shape=(), dtype=float32)
# -----------------
# ---DIST LOSS---
# tf.Tensor(0.100651726, shape=(), dtype=float32)
# -----------------
# ---TOTAL LOSS---
# tf.Tensor(9.597609, shape=(), dtype=float32)
#
# ## 02179
#
# Epoch 100
# --------------------------
# Training...
# ---NORMAL LOSS---
# tf.Tensor(4.807514, shape=(), dtype=float32)
# -----------------
# ---VERT LOSS---
# tf.Tensor(0.36674708, shape=(), dtype=float32)
# -----------------
# ---COLL LOSS---
# tf.Tensor(0.0029138895, shape=(), dtype=float32)
# -----------------
# ---EDGE LOSS---
# tf.Tensor(0.1531826, shape=(), dtype=float32)
# -----------------
# ---DIST LOSS---
# tf.Tensor(0.12792708, shape=(), dtype=float32)
# -----------------
# ---TOTAL LOSS---
# tf.Tensor(5.458285, shape=(), dtype=float32)
# -----------------
# ----------------------
# GRADS
# ----------------------
#
# ## 04846
#
# Epoch 100
# --------------------------
# Training...
# ---NORMAL LOSS---
# tf.Tensor(5.083509, shape=(), dtype=float32)
# -----------------
# ---VERT LOSS---
# tf.Tensor(0.3017217, shape=(), dtype=float32)
# -----------------
# ---COLL LOSS---
# tf.Tensor(0.010080771, shape=(), dtype=float32)
# -----------------
# ---EDGE LOSS---
# tf.Tensor(0.1691572, shape=(), dtype=float32)
# -----------------
# ---DIST LOSS---
# tf.Tensor(0.10781584, shape=(), dtype=float32)
# -----------------
# ---TOTAL LOSS---
# tf.Tensor(5.6722846, shape=(), dtype=float32)
# -----------------
# ----------------------
# GRADS
#
# ## 05207
#
# Epoch 100
# --------------------------
# Training...
# ---NORMAL LOSS---
# tf.Tensor(7.75503, shape=(), dtype=float32)
# -----------------
# ---VERT LOSS---
# tf.Tensor(0.82273716, shape=(), dtype=float32)
# -----------------
# ---COLL LOSS---
# tf.Tensor(0.0035081136, shape=(), dtype=float32)
# -----------------
# ---EDGE LOSS---
# tf.Tensor(0.38270578, shape=(), dtype=float32)
# -----------------
# ---DIST LOSS---
# tf.Tensor(0.10921732, shape=(), dtype=float32)
# -----------------
# ---TOTAL LOSS---
# tf.Tensor(9.073199, shape=(), dtype=float32)
# -----------------
# ----------------------
# GRADS
# ----------------------

# %% [markdown]
# # REGISTER TRAINS
#
# ## 00016
# Epoch 100
# --------------------------
# Training...
# ---Chamfer D. LOSS---
# tf.Tensor(7.4765115, shape=(), dtype=float32)
# -----------------
# ---VERT LOSS---
# tf.Tensor(4.7933254, shape=(), dtype=float32)
# -----------------
# ---Register vectors. LOSS---
# tf.Tensor(0.99992514, shape=(), dtype=float32)
# -----------------
# ---COLL LOSS---
# tf.Tensor(0.060638268, shape=(), dtype=float32)
# -----------------
# ---EDGE LOSS---
# tf.Tensor(0.13096592, shape=(), dtype=float32)
# -----------------
# ---TOTAL LOSS---
# tf.Tensor(13.461367, shape=(), dtype=float32)
# -----------------
# ----------------------
# GRADS
# ----------------------
#
#
# ## 01643
# Epoch 100
# --------------------------
# Training...
# ---Chamfer D. LOSS---
# tf.Tensor(5.883686, shape=(), dtype=float32)
# -----------------
# ---VERT LOSS---
# tf.Tensor(5.031674, shape=(), dtype=float32)
# -----------------
# ---Register vectors. LOSS---
# tf.Tensor(0.99986124, shape=(), dtype=float32)
# -----------------
# ---COLL LOSS---
# tf.Tensor(0.04409196, shape=(), dtype=float32)
# -----------------
# ---EDGE LOSS---
# tf.Tensor(0.24721038, shape=(), dtype=float32)
# -----------------
# ---TOTAL LOSS---
# tf.Tensor(12.206524, shape=(), dtype=float32)
# -----------------
# ----------------------
# GRADS
# ----------------------
#
#
# ## 02179
# Epoch 100
# --------------------------
# Training...
# ---Chamfer D. LOSS---
# tf.Tensor(3.7493124, shape=(), dtype=float32)
# -----------------
# ---VERT LOSS---
# tf.Tensor(3.3742354, shape=(), dtype=float32)
# -----------------
# ---Register vectors. LOSS---
# tf.Tensor(0.9999687, shape=(), dtype=float32)
# -----------------
# ---COLL LOSS---
# tf.Tensor(0.07047841, shape=(), dtype=float32)
# -----------------
# ---EDGE LOSS---
# tf.Tensor(0.11340179, shape=(), dtype=float32)
# -----------------
# ---TOTAL LOSS---
# tf.Tensor(8.307397, shape=(), dtype=float32)
# -----------------
# ----------------------
# GRADS
# ----------------------
#
#
# ## 04846
# Epoch 100
# --------------------------
# Training...
# ---Chamfer D. LOSS---
# tf.Tensor(4.329788, shape=(), dtype=float32)
# -----------------
# ---VERT LOSS---
# tf.Tensor(5.1768384, shape=(), dtype=float32)
# -----------------
# ---Register vectors. LOSS---
# tf.Tensor(0.99996024, shape=(), dtype=float32)
# -----------------
# ---COLL LOSS---
# tf.Tensor(0.05137386, shape=(), dtype=float32)
# -----------------
# ---EDGE LOSS---
# tf.Tensor(0.2648859, shape=(), dtype=float32)
# -----------------
# ---TOTAL LOSS---
# tf.Tensor(10.822847, shape=(), dtype=float32)
# -----------------
# ----------------------
# GRADS
#
#
# ## 05207
#
# Epoch 100
# --------------------------
# Training...
# ---Chamfer D. LOSS---
# tf.Tensor(9.41104, shape=(), dtype=float32)
# -----------------
# ---VERT LOSS---
# tf.Tensor(3.3697863, shape=(), dtype=float32)
# -----------------
# ---Register vectors. LOSS---
# tf.Tensor(0.9999596, shape=(), dtype=float32)
# -----------------
# ---COLL LOSS---
# tf.Tensor(0.015292238, shape=(), dtype=float32)
# -----------------
# ---EDGE LOSS---
# tf.Tensor(0.16460073, shape=(), dtype=float32)
# -----------------
# ---TOTAL LOSS---
# tf.Tensor(13.960679, shape=(), dtype=float32)
# -----------------
# ----------------------
# GRADS
# ----------------------
